# %%
import pandas as pd

# %%
new_data= { 'cars': ['Tyota', 'Volvo', 'Hyundai'], 'Types': ['SUV', 'Sedan', 'Van']}

# %%
var= pd.DataFrame(new_data)

# %%
print(var)
# Out:
#       cars  Types
# 0    Tyota    SUV
# 1    Volvo  Sedan
# 2  Hyundai    Van

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
#series

# %%
ser= [25,35,45]

# %%
ser_var= pd.Series(ser)

# %%
print (ser_var)
# Out:
# 0    25
# 1    35
# 2    45
# dtype: int64

# %%
print(ser_var[0])
# Out:
# 25

# %%
#labelling the index

# %%
ser_var= pd.Series(ser,index=('a','b','c'))

# %%
print(ser_var)
# Out:
# a    25
# b    35
# c    45
# dtype: int64

# %%
print(ser_var['b'])
# Out:
# 35

# %%
#dataframes in dictionary

# %%
months= {'Month1':['Jan','Feb'],'Month2':['Feb','Mar']}

# %%
mon_var= pd.DataFrame(months)

# %%
print(mon_var)
# Out:
#   Month1 Month2
# 0    Jan    Feb
# 1    Feb    Mar

# %%
students= {'Name': ['Ifti','Sundar','Priyanshu','Harsh'], 'RoomNo':[109,109,216,200]}

# %%
new_var=pd.DataFrame(students)

# %%
print(new_var)
# Out:
#         Name  RoomNo
# 0       Ifti     109
# 1     Sundar     109
# 2  Priyanshu     216
# 3      Harsh     200

# %%
print(new_var.loc[[0,1]]) #returns as series if use one index
# Out:
#      Name  RoomNo
# 0    Ifti     109
# 1  Sundar     109

# %%
#READING_CSV

# %%
df=pd.read_csv("D:\\archive\\heart_disease.csv")

# %%
print(df.to_string())
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking Family Heart Disease Diabetes        BMI High Blood Pressure Low HDL Cholesterol High LDL Cholesterol Alcohol Consumption Stress Level  Sleep Hours Sugar Consumption  Triglyceride Level  Fasting Blood Sugar  CRP Level  Homocysteine Level Heart Disease Status
# 0     56.0    Male           153.0              155.0            High     Yes                  Yes       No  24.991591                 Yes                 Yes                   No                High       Medium     7.633228            Medium               342.0                  NaN  12.969246           12.387250                   No
# ...

# %%
pd.options.display.max_rows=999

# %%
print(df)
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
#reading Json

# %%
json_data=pd.read_json("D:\\archive\\data.json")

# %%
print(json_data.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(json_data)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(json_data.head()) #viewing first 5 rows
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(json_data.tail()) #viewing the last 5 rows
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
print(json_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB
# None
